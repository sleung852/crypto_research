# %% [markdown]
# To work out the fundamental relationships between difference cryptos

# %% [markdown]
# Part 1: BTC and ETH

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
start = '2018-01-01'

# %%
def hist_r(ticker):
    full_data = pd.read_csv(r'data 041018\{}.csv'.format(str(ticker)))
    price = full_data[['date','price(USD)']].set_index('date')
    return (price.pct_change()[1:])

# %%
def hist_p(ticker):
    full_data = pd.read_csv(r'data 041018\{}.csv'.format(str(ticker)))
    price = full_data[['date','price(USD)']].set_index('date')
    return (price)

# %%
eth_r = hist_r('eth')
btc_r = hist_r('btc')

# %%
eth_r.index = pd.to_datetime(eth_r.index)
btc_r.index = pd.to_datetime(btc_r.index)

# %%
eth_r16 = eth_r.iloc[eth_r.index>start]
btc_r16 = btc_r.iloc[btc_r.index>start]

# %%
fig, ax1 = plt.subplots()
plt.plot(btc_r16, alpha=0.8)
plt.plot(eth_r16, alpha=0.5)

plt.xlabel('Dates')
plt.ylabel('Returns')
plt.legend(['BTC','ETH'])

fig.autofmt_xdate()

# %%
_, ax2 = plt.subplots()
plt.plot(btc_p)

# %%
eth_p = hist_p('eth')
btc_p = hist_p('btc')

eth_p16 = eth_p.loc[eth_p.index>start]
btc_p16 = btc_p.loc[btc_p.index>start]

# %%
import numpy as np
from statsmodels import regression
import statsmodels.api as sm
import math

# %%
#pick the model
Y = btc_p16
X = eth_p16
x_c = sm.add_constant(x)
lr_model = regression.linear_model.OLS(Y,x_c).fit()
lr_model.params
# Out:
# const         806.308765
# price(USD)     12.754781
# dtype: float64

# %%
# y = mx + c
c = lr_model.params[0]
m = lr_model.params[1]

# %%
X2 = np.linspace(X.min(), X.max(), 100)
Y_hat = m*X2 + c

# %%
plt.scatter(eth_p16, btc_p16, alpha = 0.3)
plt.plot(X2,Y_hat,'r',alpha=0.8)

plt.ylabel('BTC Price')
plt.xlabel('ETH Price')
# Out:
# Text(0.5,0,'ETH Price')

# %%
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price(USD)   R-squared:                       0.828
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     4825.
# Date:                Thu, 04 Oct 2018   Prob (F-statistic):               0.00
# Time:                        12:05:02   Log-Likelihood:                -8901.4
# No. Observations:                1005   AIC:                         1.781e+04
# Df Residuals:                    1003   BIC:                         1.782e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        806.3088     70.138     11.496      0.000     668.675     943.943
# price(USD)    12.7548      0.184     69.460      0.000      12.394      13.115
# ==============================================================================
# Omnibus:                      513.667   Durbin-Watson:                   0.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4674.180
# Skew:                           2.158   Prob(JB):                         0.00
# Kurtosis:                      12.643   Cond. No.                         499.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
def lr_model_analysis(x_name,y_name,start):
    #obtain the price data
    X = hist_r(x_name)
    Y = hist_r(y_name)
    X = X.loc[X.index>start]
    Y = Y.loc[Y.index>start]
    #setup for regression
    X_c = sm.add_constant(X)
    lr_model = regression.linear_model.OLS(Y,X_c).fit()
    # y = mx + c
    c = lr_model.params[0]
    m = lr_model.params[1]
    #plot
    X2 = np.linspace(X.min(), X.max(), 50)
    Y_hat = m*X2 + c
    plt.scatter(X, Y, alpha = 0.3)
    plt.plot(X2,Y_hat,'r',alpha=0.8)
    #label
    plt.ylabel('{} Price'.format(str(y_name)))
    plt.xlabel('{} Price'.format(str(x_name)))
    return(lr_model.summary())

# %%
lr_model_analysis('eos','btc',start)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price(USD)   R-squared:                       0.426
# Model:                            OLS   Adj. R-squared:                  0.424
# Method:                 Least Squares   F-statistic:                     201.7
# Date:                Thu, 04 Oct 2018   Prob (F-statistic):           1.25e-34
# Time:                        12:23:23   Log-Likelihood:                 547.06
# No. Observations:                 274   AIC:                            -1090.
# Df Residuals:                     272   BIC:                            -1083.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.002     -1.231      0.219      -0.006       0.001
# price(USD)     0.3344      0.024     14.203      0.000       0.288       0.381
# ==============================================================================
# Omnibus:                       24.280   Durbin-Watson:                   2.153
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.821
# Skew:                           0.198   Prob(JB):                     8.51e-20
# Kurtosis:                       5.745   Cond. No.                         11.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
